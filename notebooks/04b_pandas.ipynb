# %% [markdown]
# # Data Manipulation with Pandas & Visualization with Matplotlib & Seaborn
#
# **Date:** 05/11/2025

# %%
#pip install pandas numpy matplotlib seaborn

# %%
from math import pi
print(pi)
# Out:
# 3.141592653589793

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
help(dir)
# Out:
# Help on built-in function dir in module builtins:
#
# dir(...)
#     Show attributes of an object.
#
#     If called without an argument, return the names in the current scope.
#     Else, return an alphabetized list of names comprising (some of) the attributes
#     of the given object, and of attributes reachable from it.
#     If the object supplies a method named __dir__, it will be used; otherwise
#     the default dir() logic is used and returns:
#       for a module object: the module's attributes.
#       for a class object:  its attributes, and recursively the attributes
#         of its bases.
#       for any other object: its attributes, its class's attributes, and
#         recursively the attributes of its class's base classes.

# %%
dir(pd)
# Out:
# ['ArrowDtype',
#  'BooleanDtype',
#  'Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Flags',
#  'Float32Dtype',
#  'Float64Dtype',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NA',
#  'NaT',
#  'NamedAgg',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseDtype',
#  'StringDtype',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt8Dtype',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__git_version__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_built_with_meson',
#  '_config',
#  '_is_numpy_dev',
#  '_libs',
#  '_pandas_datetime_CAPI',
#  '_pandas_parser_CAPI',
#  '_testing',
#  '_typing',
#  '_version_meson',
#  'annotations',
#  'api',
#  'array',
#  'arrays',
#  'bdate_range',
#  'compat',
#  'concat',
#  'core',
#  'crosstab',
#  'cut',
#  'date_range',
#  'describe_option',
#  'errors',
#  'eval',
#  'factorize',
#  'from_dummies',
#  'get_dummies',
#  'get_option',
#  'infer_freq',
#  'interval_range',
#  'io',
#  'isna',
#  'isnull',
#  'json_normalize',
#  'lreshape',
#  'melt',
#  'merge',
#  'merge_asof',
#  'merge_ordered',
#  'notna',
#  'notnull',
#  'offsets',
#  'option_context',
#  'options',
#  'pandas',
#  'period_range',
#  'pivot',
#  'pivot_table',
#  'plotting',
#  'qcut',
#  'read_clipboard',
#  'read_csv',
#  'read_excel',
#  'read_feather',
#  'read_fwf',
#  'read_gbq',
#  'read_hdf',
#  'read_html',
#  'read_json',
#  'read_orc',
#  'read_parquet',
#  'read_pickle',
#  'read_sas',
#  'read_spss',
#  'read_sql',
#  'read_sql_query',
#  'read_sql_table',
#  'read_stata',
#  'read_table',
#  'read_xml',
#  'reset_option',
#  'set_eng_float_format',
#  'set_option',
#  'show_versions',
#  'test',
#  'testing',
#  'timedelta_range',
#  'to_datetime',
#  'to_numeric',
#  'to_pickle',
#  'to_timedelta',
#  'tseries',
#  'unique',
#  'util',
#  'value_counts',
#  'wide_to_long']

# %% [markdown]
# * Melb Data: https://www.kaggle.com/code/dansbecker/handling-missing-values/data?select=melb_data.csv
# * Pandas Documentation: https://pandas.pydata.org/docs/
# * Pandas Cheat Sheet: https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf

# %%
DATA_PATH = os.path.join(
    "/Users/cesar/sandbox/ai_programming_foundations/data",
    "melb_data.csv"
)

# %%
df = pd.read_csv(DATA_PATH)

# %% [markdown]
# Nota: Los objetos de Pandas se llaman **DataFrames**

# %%
df #.tail(5)
# Out:
#               Suburb           Address  Rooms Type    Price Method   SellerG  \
# 0         Abbotsford      85 Turner St      2    h  1480000      S    Biggin
# 1         Abbotsford   25 Bloomburg St      2    h  1035000      S    Biggin
# 2         Abbotsford      5 Charles St      3    h  1465000     SP    Biggin
# 3         Abbotsford  40 Federation La      3    h   850000     PI    Biggin
# 4         Abbotsford       55a Park St      4    h  1600000     VB    Nelson
# ...              ...               ...    ...  ...      ...    ...       ...
# 13575  Wheelers Hill      12 Strada Cr      4    h  1245000      S     Barry
# 13576   Williamstown     77 Merrett Dr      3    h  1031000     SP  Williams
# 13577   Williamstown       83 Power St      3    h  1170000      S     Raine
# 13578   Williamstown      96 Verdon St      4    h  2500000     PI   Sweeney
# 13579     Yarraville        6 Agnes St      4    h  1285000     SP   Village
#
#             Date  Distance  Postcode  ...  BuildingArea  YearBuilt  \
# 0     2016-03-12       2.5      3067  ...           NaN        NaN
# 1     2016-04-02       2.5      3067  ...          79.0     1900.0
# 2     2017-04-03       2.5      3067  ...         150.0     1900.0
# 3     2017-04-03       2.5      3067  ...           NaN        NaN
# 4     2016-04-06       2.5      3067  ...         142.0     2014.0
# ...          ...       ...       ...  ...           ...        ...
# 13575 2017-08-26      16.7      3150  ...           NaN     1981.0
# 13576 2017-08-26       6.8      3016  ...         133.0     1995.0
# 13577 2017-08-26       6.8      3016  ...           NaN     1997.0
# 13578 2017-08-26       6.8      3016  ...         157.0     1920.0
# 13579 2017-08-26       6.3      3013  ...         112.0     1920.0
#
#        CouncilArea  Lattitude  Longtitude                  Regionname  \
# 0            Yarra  -37.79960   144.99840       Northern Metropolitan
# 1            Yarra  -37.80790   144.99340       Northern Metropolitan
# 2            Yarra  -37.80930   144.99440       Northern Metropolitan
# 3            Yarra  -37.79690   144.99690       Northern Metropolitan
# 4            Yarra  -37.80720   144.99410       Northern Metropolitan
# ...            ...        ...         ...                         ...
# 13575          NaN  -37.90562   145.16761  South-Eastern Metropolitan
# 13576          NaN  -37.85927   144.87904        Western Metropolitan
# 13577          NaN  -37.85274   144.88738        Western Metropolitan
# 13578          NaN  -37.85908   144.89299        Western Metropolitan
# 13579          NaN  -37.81188   144.88449        Western Metropolitan
#
#       Propertycount  year  month day
# 0              4019  2016      3  12
# 1              4019  2016      4   2
# 2              4019  2017      4   3
# 3              4019  2017      4   3
# 4              4019  2016      4   6
# ...             ...   ...    ...  ..
# 13575          7392  2017      8  26
# 13576          6380  2017      8  26
# 13577          6380  2017      8  26
# 13578          6380  2017      8  26
# 13579          6543  2017      8  26
#
# [13580 rows x 24 columns]

# %%
df.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
len(df.columns) # Cantidad de columns
# Out:
# 21

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         13580 non-null  object
#  1   Address        13580 non-null  object
#  2   Rooms          13580 non-null  int64
#  3   Type           13580 non-null  object
#  4   Price          13580 non-null  int64
#  5   Method         13580 non-null  object
#  6   SellerG        13580 non-null  object
#  7   Date           13580 non-null  object
#  8   Distance       13580 non-null  float64
#  9   Postcode       13580 non-null  int64
#  10  Bedroom2       13580 non-null  int64
#  11  Bathroom       13580 non-null  int64
#  12  Car            13518 non-null  float64
#  13  Landsize       13580 non-null  int64
#  14  BuildingArea   7130 non-null   float64
#  15  YearBuilt      8205 non-null   float64
#  16  CouncilArea    12211 non-null  object
#  17  Lattitude      13580 non-null  float64
#  18  Longtitude     13580 non-null  float64
#  19  Regionname     13580 non-null  object
#  20  Propertycount  13580 non-null  int64
# dtypes: float64(6), int64(7), object(8)
# memory usage: 2.2+ MB

# %%
df.describe()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  13580.000000  1.358000e+04  13580.000000  13580.000000  13580.000000
# mean       2.937997  1.075684e+06     10.137776   3105.301915      2.914728
# std        0.955748  6.393107e+05      5.868725     90.676964      0.965921
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.500000e+05      6.100000   3044.000000      2.000000
# 50%        3.000000  9.030000e+05      9.200000   3084.000000      3.000000
# 75%        3.000000  1.330000e+06     13.000000   3148.000000      3.000000
# max       10.000000  9.000000e+06     48.100000   3977.000000     20.000000
#
#            Bathroom           Car       Landsize  BuildingArea    YearBuilt  \
# count  13580.000000  13518.000000   13580.000000   7130.000000  8205.000000
# mean       1.534242      1.610075     558.416127    151.967650  1964.684217
# std        0.691712      0.962634    3990.669241    541.014538    37.273762
# min        0.000000      0.000000       0.000000      0.000000  1196.000000
# 25%        1.000000      1.000000     177.000000     93.000000  1940.000000
# 50%        1.000000      2.000000     440.000000    126.000000  1970.000000
# 75%        2.000000      2.000000     651.000000    174.000000  1999.000000
# max        8.000000     10.000000  433014.000000  44515.000000  2018.000000
#
#           Lattitude    Longtitude  Propertycount
# count  13580.000000  13580.000000   13580.000000
# mean     -37.809203    144.995216    7454.417378
# std        0.079260      0.103916    4378.581772
# min      -38.182550    144.431810     249.000000
# 25%      -37.856822    144.929600    4380.000000
# 50%      -37.802355    145.000100    6555.000000
# 75%      -37.756400    145.058305   10331.000000
# max      -37.408530    145.526350   21650.000000

# %%
np.mean(df["Price"])
# Out:
# np.float64(1075684.079455081)

# %%
df["Price"].mean()
# Out:
# np.float64(1075684.079455081)

# %%
df["Price"]
# Out:
# 0        1480000
# 1        1035000
# 2        1465000
# 3         850000
# 4        1600000
#           ...
# 13575    1245000
# 13576    1031000
# 13577    1170000
# 13578    2500000
# 13579    1285000
# Name: Price, Length: 13580, dtype: int64

# %%
np.sum(df["Rooms"])
# Out:
# np.int64(39898)

# %%
df["Rooms"].sum()
# Out:
# np.int64(39898)

# %% [markdown]
# **Nota Importante:**
#
# * Pandas trabaja con una representación de datos tabulares (es decir, tablas) usando Numpy para cargar, manipular y transformar los datos:

# %%
df.to_numpy()
# Out:
# array([['Abbotsford', '85 Turner St', 2, ..., 144.9984,
#         'Northern Metropolitan', 4019],
#        ['Abbotsford', '25 Bloomburg St', 2, ..., 144.9934,
#         'Northern Metropolitan', 4019],
#        ['Abbotsford', '5 Charles St', 3, ..., 144.9944,
#         'Northern Metropolitan', 4019],
#        ...,
#        ['Williamstown', '83 Power St', 3, ..., 144.88738,
#         'Western Metropolitan', 6380],
#        ['Williamstown', '96 Verdon St', 4, ..., 144.89299,
#         'Western Metropolitan', 6380],
#        ['Yarraville', '6 Agnes St', 4, ..., 144.88449,
#         'Western Metropolitan', 6543]], shape=(13580, 21), dtype=object)

# %%
df[["Rooms", "Price", "Distance"]]
# Out:
#        Rooms    Price  Distance
# 0          2  1480000       2.5
# 1          2  1035000       2.5
# 2          3  1465000       2.5
# 3          3   850000       2.5
# 4          4  1600000       2.5
# ...      ...      ...       ...
# 13575      4  1245000      16.7
# 13576      3  1031000       6.8
# 13577      3  1170000       6.8
# 13578      4  2500000       6.8
# 13579      4  1285000       6.3
#
# [13580 rows x 3 columns]

# %%
df[["Rooms", "Price", "Distance"]].to_numpy()
# Out:
# array([[2.000e+00, 1.480e+06, 2.500e+00],
#        [2.000e+00, 1.035e+06, 2.500e+00],
#        [3.000e+00, 1.465e+06, 2.500e+00],
#        ...,
#        [3.000e+00, 1.170e+06, 6.800e+00],
#        [4.000e+00, 2.500e+06, 6.800e+00],
#        [4.000e+00, 1.285e+06, 6.300e+00]], shape=(13580, 3))

# %% [markdown]
# Podemos consultar subconjuntos de columnas de dos formas: a) usando una lista de columnas, b) usando el método `.filter(...)`

# %%
my_columns = ["Rooms", "Price", "Distance"]
df[["Rooms", "Price", "Distance"]]
# Out:
#        Rooms    Price  Distance
# 0          2  1480000       2.5
# 1          2  1035000       2.5
# 2          3  1465000       2.5
# 3          3   850000       2.5
# 4          4  1600000       2.5
# ...      ...      ...       ...
# 13575      4  1245000      16.7
# 13576      3  1031000       6.8
# 13577      3  1170000       6.8
# 13578      4  2500000       6.8
# 13579      4  1285000       6.3
#
# [13580 rows x 3 columns]

# %%
df.filter(my_columns)
# Out:
#        Rooms    Price  Distance
# 0          2  1480000       2.5
# 1          2  1035000       2.5
# 2          3  1465000       2.5
# 3          3   850000       2.5
# 4          4  1600000       2.5
# ...      ...      ...       ...
# 13575      4  1245000      16.7
# 13576      3  1031000       6.8
# 13577      3  1170000       6.8
# 13578      4  2500000       6.8
# 13579      4  1285000       6.3
#
# [13580 rows x 3 columns]

# %% [markdown]
# Adicionalmente podemos consultad muestras de los datos con `.head(...)`, `.tail(...)` o `.sample(...)`

# %% [markdown]
# # Modificando columnas
#
# Se puede acceder a las columnas por nombre. Nota como nos regresa el tipo de dato de Numpy `dtype`:

# %%
df["Suburb"]
# Out:
# 0           Abbotsford
# 1           Abbotsford
# 2           Abbotsford
# 3           Abbotsford
# 4           Abbotsford
#              ...
# 13575    Wheelers Hill
# 13576     Williamstown
# 13577     Williamstown
# 13578     Williamstown
# 13579       Yarraville
# Name: Suburb, Length: 13580, dtype: object

# %%
df["Suburb"].str.lower()
# Out:
# 0           abbotsford
# 1           abbotsford
# 2           abbotsford
# 3           abbotsford
# 4           abbotsford
#              ...
# 13575    wheelers hill
# 13576     williamstown
# 13577     williamstown
# 13578     williamstown
# 13579       yarraville
# Name: Suburb, Length: 13580, dtype: object

# %%
df["Suburb"].str.upper()
# Out:
# 0           ABBOTSFORD
# 1           ABBOTSFORD
# 2           ABBOTSFORD
# 3           ABBOTSFORD
# 4           ABBOTSFORD
#              ...
# 13575    WHEELERS HILL
# 13576     WILLIAMSTOWN
# 13577     WILLIAMSTOWN
# 13578     WILLIAMSTOWN
# 13579       YARRAVILLE
# Name: Suburb, Length: 13580, dtype: object

# %%
df["Date"].sample(10) # Esta columna contiene fechas, pero no fue interpretado en formato fecha
# Out:
# 11278    15/07/17
# 10198    27/05/17
# 8742     01/07/17
# 11710    22/07/17
# 9093     03/06/17
# 5765     03/09/16
# 5391     22/08/16
# 6636     04/03/17
# 7391     28/08/16
# 3911     07/05/16
# Name: Date, dtype: object

# %%
df["Date"].to_string()
# Out:
# '0        03/12/16\n1        04/02/16\n2        04/03/17\n3        04/03/17\n4        04/06/16\n5        07/05/16\n6        07/05/16\n7        08/10/16\n8        08/10/16\n9        08/10/16\n10       12/11/16\n11       12/11/16\n12       12/11/16\n13       13/08/16\n14       14/05/16\n15       15/10/16\n16       16/07/16\n17       16/07/16\n18       17/09/16\n19       17/09/16\n20       18/03/17\n21       18/03/17\n22       18/03/17\n23       18/06/16\n24       18/06/16\n25       19/11/16\n26       22/08/16\n27       22/08/16\n28       22/08/16\n29       22/08/16\n30       24/09/16\n31       25/02/17\n32       25/02/17\n33       26/07/16\n34       27/11/16\n35       27/11/16\n36       28/05/16\n37       30/07/16\n38       03/09/16\n39       03/12/16\n40       04/03/17\n41       04/03/17\n42       04/03/17\n43       04/03/17\n44       04/03/17\n45       06/08/16\n46       06/08/16\n47       07/05/16\n48       07/05/16\n49       07/11/16\n50       10/09/16\n51       10/09/16\n52       10/12/16\n53       11/02/17\n54       13/08/16\n55       14/05/16\n56       15/10/16\n57       16/04/16\n58       16/07/16\n59       16/07/16\n60       16/07/16\n61       16/07/16\n62       17/09/16\n63       17/09/16\n64       18/03/17\n65       18/03/17\n66       18/03/17\n67       18/06/16\n68       19/11/16\n69       22/05/16\n70       22/08/16\n71       22/08/16\n72       22/08/16\n73       23/04/16\n74       24/09/16\n75       25/02/17\n76       27/11/16\n77       27/11/16\n78       03/09/16\n79       03/09/16\n80       04/03/17\n81       04/03/17\n82       04/03/17\n83       06/08/16\n84       07/05/16\n85       07/05/16\n86       07/11/16\n87       07/11/16\n88       10/09/16\n89       10/09/16\n90       10/09/16\n91       10/12/16\n92       10/12/16\n93       10/12/16\n94       10/12/16\n95       12/06/16\n96       12/11/16\n97       15/10/16\n98       15/10/16\n99       15/10/16\n100      16/04/16\n101      18/03/17\n102      18/03/17\n103      18/06/16\n104      22/05/16\n105      23/04/16\n106      24/09/16\n107      25/02/17\n108      25/02/17\n109      25/02/17\n110      25/02/17\n111      26/07/16\n112      26/07/16\n113      27/06/16\n114      27/11/16\n115      28/05/16\n116      28/08/16\n117      28/08/16\n118      30/07/16\n119      30/07/16\n120      03/09/16\n121      03/09/16\n122      04/03/17\n123      08/10/16\n124      12/06/16\n125      12/11/16\n126      12/11/16\n127      12/11/16\n128      15/10/16\n129      16/04/16\n130      18/03/17\n131      19/11/16\n132      19/11/16\n133      22/05/16\n134      22/05/16\n135      24/09/16\n136      25/02/17\n137      27/06/16\n138      27/11/16\n139      28/08/16\n140      30/07/16\n141      03/09/16\n142      03/12/16\n143      04/02/16\n144      04/03/17\n145      04/06/16\n146      04/06/16\n147      06/08/16\n148      06/08/16\n149      07/05/16\n150      07/11/16\n151      08/10/16\n152      08/10/16\n153      08/10/16\n154      10/09/16\n155      10/09/16\n156      10/09/16\n157      10/12/16\n158      11/02/17\n159      11/02/17\n160      11/02/17\n161      11/02/17\n162      12/11/16\n163      13/08/16\n164      14/05/16\n165      14/05/16\n166      15/10/16\n167      16/04/16\n168      16/04/16\n169      16/07/16\n170      17/09/16\n171      18/03/17\n172      19/11/16\n173      22/05/16\n174      22/08/16\n175      23/04/16\n176      25/02/17\n177      25/02/17\n178      27/06/16\n179      27/11/16\n180      28/05/16\n181      28/05/16\n182      28/05/16\n183      28/08/16\n184      28/08/16\n185      30/07/16\n186      03/09/16\n187      03/09/16\n188      04/03/17\n189      04/03/17\n190      04/03/17\n191      04/06/16\n192      04/06/16\n193      06/08/16\n194      07/05/16\n195      07/11/16\n196      08/10/16\n197      10/12/16\n198      11/03/17\n199      12/06/16\n200      14/05/16\n201      15/10/16\n202      15/10/16\n203      19/11/16\n204      19/11/16\n205      22/05/16\n206      22/05/16\n207      22/08/16\n208      22/08/16\n209      22/08/16\n210       ...

# %%
df["Date"] = pd.to_datetime(df["Date"])
# Out:
# /var/folders/xp/09_m9yj956x3kbv7qgpqgd6r0000gn/T/ipykernel_80426/936118274.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["Date"] = pd.to_datetime(df["Date"])

# %%
df["Date"]
# Out:
# 0       2016-03-12
# 1       2016-04-02
# 2       2017-04-03
# 3       2017-04-03
# 4       2016-04-06
#            ...
# 13575   2017-08-26
# 13576   2017-08-26
# 13577   2017-08-26
# 13578   2017-08-26
# 13579   2017-08-26
# Name: Date, Length: 13580, dtype: datetime64[ns]

# %%
df["year"] = df["Date"].dt.year
df["month"] = df["Date"].dt.month
df["day"] = df["Date"].dt.day

# %%
df.filter(["Date", "year", "month", "day"])
# Out:
#             Date  year  month  day
# 0     2016-03-12  2016      3   12
# 1     2016-04-02  2016      4    2
# 2     2017-04-03  2017      4    3
# 3     2017-04-03  2017      4    3
# 4     2016-04-06  2016      4    6
# ...          ...   ...    ...  ...
# 13575 2017-08-26  2017      8   26
# 13576 2017-08-26  2017      8   26
# 13577 2017-08-26  2017      8   26
# 13578 2017-08-26  2017      8   26
# 13579 2017-08-26  2017      8   26
#
# [13580 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 24 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         13580 non-null  object
#  1   Address        13580 non-null  object
#  2   Rooms          13580 non-null  int64
#  3   Type           13580 non-null  object
#  4   Price          13580 non-null  int64
#  5   Method         13580 non-null  object
#  6   SellerG        13580 non-null  object
#  7   Date           13580 non-null  datetime64[ns]
#  8   Distance       13580 non-null  float64
#  9   Postcode       13580 non-null  int64
#  10  Bedroom2       13580 non-null  int64
#  11  Bathroom       13580 non-null  int64
#  12  Car            13518 non-null  float64
#  13  Landsize       13580 non-null  int64
#  14  BuildingArea   7130 non-null   float64
#  15  YearBuilt      8205 non-null   float64
#  16  CouncilArea    12211 non-null  object
#  17  Lattitude      13580 non-null  float64
#  18  Longtitude     13580 non-null  float64
#  19  Regionname     13580 non-null  object
#  20  Propertycount  13580 non-null  int64
#  21  year           13580 non-null  int32
#  22  month          13580 non-null  int32
#  23  day            13580 non-null  int32
# dtypes: datetime64[ns](1), float64(6), int32(3), int64(7), object(7)
# memory usage: 2.3+ MB

# %% [markdown]
# Otras transformaciones como pivots tambien son posibles:

# %%
data_example = pd.DataFrame({
 "kpi_1": ["a", "b", "c", "d", "e", "f"],
 "kpi_2": [1, 1, 2, 1, 1, 2],
 "kpi_3": [1, 2, 1, 2, 1, 2],
 "kpi_4": [1, 2, 3, 4, 5, 6],
 "level": [0, 1, 2, 3, 4, 5]})

data_example
# Out:
#   kpi_1  kpi_2  kpi_3  kpi_4  level
# 0     a      1      1      1      0
# 1     b      1      2      2      1
# 2     c      2      1      3      2
# 3     d      1      2      4      3
# 4     e      1      1      5      4
# 5     f      2      2      6      5

# %%
data_example.pivot(index="kpi_1", columns=["kpi_2"], values="level")
# Out:
# kpi_2    1    2
# kpi_1
# a      0.0  NaN
# b      1.0  NaN
# c      NaN  2.0
# d      3.0  NaN
# e      4.0  NaN
# f      NaN  5.0

# %% [markdown]
# ## Gráficos usando Python y MatplotLib

# %%
# figura y eje de la figura
fig, ax = plt.subplots(figsize=(10, 5))

# numero de intervalos para conteos
n_bins = 100

# creacion del objeto historgama
n, bins, patches = ax.hist(
    df['Price'],
    n_bins
    )

ax.set_title('Fig.1 Histograma de frequencias de Price')
ax.set_xlabel('Price de las casas')
ax.set_ylabel('# Ocurrencias')
# Out:
# Text(0, 0.5, '# Ocurrencias')

# %%
fig, ax = plt.subplots(figsize=(15, 6))
n_bins = 300

# plot the cumulative histogram
n, bins, patches = ax.hist(
    df['Price'],
    n_bins,
    density=True,
    histtype='step',
    cumulative=True,
    label='Empirical'
    )

# tidy up the figure
ax.grid(True)
ax.legend(loc='right')
ax.set_title('Fig. 3 Función de distribución acumulativa empírica')
ax.set_xlabel('Price de las casas')
ax.set_ylabel('Proporción de ocurrencia')

plt.show()

# %%
sns.histplot(data=df, x="Price")
# Out:
# <Axes: xlabel='Price', ylabel='Count'>

# %%
sns.ecdfplot(data=df, x="Price")
# Out:
# <Axes: xlabel='Price', ylabel='Proportion'>

# %% [markdown]
# Existe la posibilidad de hacer estadisticos agregados como conteos agregados:

# %%
df.groupby("Regionname")["Address"].count()
# Out:
# Regionname
# Eastern Metropolitan          1471
# Eastern Victoria                53
# Northern Metropolitan         3890
# Northern Victoria               41
# South-Eastern Metropolitan     450
# Southern Metropolitan         4695
# Western Metropolitan          2948
# Western Victoria                32
# Name: Address, dtype: int64

# %%
sns.countplot(y="Regionname", data=df)
# Out:
# <Axes: xlabel='count', ylabel='Regionname'>

# %%
df.groupby("CouncilArea")["Price"].mean() # Precio promedo por Council Area
# Out:
# CouncilArea
# Banyule              9.444280e+05
# Bayside              1.652168e+06
# Boroondara           1.647217e+06
# Brimbank             6.472007e+05
# Cardinia             5.731250e+05
# Casey                6.564079e+05
# Darebin              9.158000e+05
# Frankston            6.589849e+05
# Glen Eira            1.069279e+06
# Greater Dandenong    6.970673e+05
# Hobsons Bay          1.000933e+06
# Hume                 5.614067e+05
# Kingston             9.776128e+05
# Knox                 8.948961e+05
# Macedon Ranges       6.315714e+05
# Manningham           1.235161e+06
# Maribyrnong          8.116988e+05
# Maroondah            8.510250e+05
# Melbourne            9.255224e+05
# Melton               4.996227e+05
# Monash               1.168289e+06
# Moonee Valley        9.873404e+05
# Moorabool            2.850000e+05
# Moreland             8.265576e+05
# Nillumbik            8.593194e+05
# Port Phillip         1.144346e+06
# Stonnington          1.293382e+06
# Unavailable          1.325000e+06
# Whitehorse           1.234218e+06
# Whittlesea           6.307563e+05
# Wyndham              5.318134e+05
# Yarra                1.127605e+06
# Yarra Ranges         7.463601e+05
# Name: Price, dtype: float64

# %%
sns.barplot(x="Price", y="CouncilArea", data=df)
# Out:
# <Axes: xlabel='Price', ylabel='CouncilArea'>

# %%
df.groupby("month")["Price"].mean()
# Out:
# month
# 1     9.397921e+05
# 2     1.169051e+06
# 3     1.146762e+06
# 4     1.050479e+06
# 5     1.097807e+06
# 6     1.068981e+06
# 7     9.314698e+05
# 8     1.056371e+06
# 9     1.126349e+06
# 10    1.135970e+06
# 11    1.142503e+06
# 12    1.144737e+06
# Name: Price, dtype: float64

# %%
sns.lineplot(
    x="month",
    y="Price",
    data=df)
# Out:
# <Axes: xlabel='month', ylabel='Price'>

# %%
sns.lineplot(
    x="month",
    y="Price",
    hue="year",
    data=df)
# Out:
# <Axes: xlabel='month', ylabel='Price'>

# %%
sns.lineplot(
    x="month",
    y="Price",
    hue="year",
    data=df)
# Out:
# <Axes: xlabel='month', ylabel='Price'>

# %%
sns.scatterplot(x="Distance", y="Price", data=df)
# Out:
# <Axes: xlabel='Distance', ylabel='Price'>

# %%
sns.scatterplot(x="Distance", y="Price", hue="Regionname", data=df)
# Out:
# <Axes: xlabel='Distance', ylabel='Price'>

# %%
df_plot = df.filter(["Price", "Distance", "Landsize", "Regionname"])

# %%
df_plot
# Out:
#          Price  Distance  Landsize                  Regionname
# 0      1480000       2.5       202       Northern Metropolitan
# 1      1035000       2.5       156       Northern Metropolitan
# 2      1465000       2.5       134       Northern Metropolitan
# 3       850000       2.5        94       Northern Metropolitan
# 4      1600000       2.5       120       Northern Metropolitan
# ...        ...       ...       ...                         ...
# 13575  1245000      16.7       652  South-Eastern Metropolitan
# 13576  1031000       6.8       333        Western Metropolitan
# 13577  1170000       6.8       436        Western Metropolitan
# 13578  2500000       6.8       866        Western Metropolitan
# 13579  1285000       6.3       362        Western Metropolitan
#
# [13580 rows x 4 columns]

# %%
sns.pairplot(data= df_plot)

# %%
sns.pairplot(data= df_plot, hue="Regionname")

# %%
sns.boxplot(
    data=df,
    y="Regionname",
    x="Price",
    hue="Regionname",
    showfliers = False
    ).set(
        title='Fig. Diagramas de caja del Precio vs Region'
        )
# Out:
# [Text(0.5, 1.0, 'Fig. Diagramas de caja del Precio vs Region')]

# %%
df_numeric = df[["Price", "Rooms", "Distance", "Bathroom", "Car", "Landsize"]]

# %%
corr = df_numeric.corr()

# %%
#sns.scatterplot(data=df, x="Rooms", y="Bathroom")

# %%
sns.heatmap(corr, annot=True, fmt=".1f", cmap = 'coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# La data contiene valores nulos:

# %%
df.isnull().sum()
# Out:
# Suburb              0
# Address             0
# Rooms               0
# Type                0
# Price               0
# Method              0
# SellerG             0
# Date                0
# Distance            0
# Postcode            0
# Bedroom2            0
# Bathroom            0
# Car                62
# Landsize            0
# BuildingArea     6450
# YearBuilt        5375
# CouncilArea      1369
# Lattitude           0
# Longtitude          0
# Regionname          0
# Propertycount       0
# year                0
# month               0
# day                 0
# dtype: int64

# %%
df["BuildingArea"]
# Out:
# 0          NaN
# 1         79.0
# 2        150.0
# 3          NaN
# 4        142.0
#          ...
# 13575      NaN
# 13576    133.0
# 13577      NaN
# 13578    157.0
# 13579    112.0
# Name: BuildingArea, Length: 13580, dtype: float64

# %%
df["BuildingArea"].fillna(0)
# Out:
# 0          0.0
# 1         79.0
# 2        150.0
# 3          0.0
# 4        142.0
#          ...
# 13575      0.0
# 13576    133.0
# 13577      0.0
# 13578    157.0
# 13579    112.0
# Name: BuildingArea, Length: 13580, dtype: float64

# %%
mean_building_area = np.mean(df["BuildingArea"])
df["BuildingArea"].fillna(mean_building_area)
# Out:
# 0        151.96765
# 1         79.00000
# 2        150.00000
# 3        151.96765
# 4        142.00000
#            ...
# 13575    151.96765
# 13576    133.00000
# 13577    151.96765
# 13578    157.00000
# 13579    112.00000
# Name: BuildingArea, Length: 13580, dtype: float64

# %%
df.shape
# Out:
# (13580, 24)

# %%
df.dropna().shape
# Out:
# (6196, 24)

# %%
df.size
# Out:
# 325920

# %%
df.dropna().size
# Out:
# 148704

# %% [markdown]
# **Questions**
#
# * Usa lo aqui expuesta para carga la data de tu proyecto,
# * Explora los datos al interior y empieza a generar insights respecto a que variables crees que serian importantes para predecir el precio de las casas.
