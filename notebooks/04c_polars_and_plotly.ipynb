# %%
pip install polars
# Out:
# Collecting polars
#   Downloading polars-1.35.1-py3-none-any.whl.metadata (10 kB)
# Collecting polars-runtime-32==1.35.1 (from polars)
#   Downloading polars_runtime_32-1.35.1-cp39-abi3-macosx_10_12_x86_64.whl.metadata (1.5 kB)
# Downloading polars-1.35.1-py3-none-any.whl (783 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 783.6/783.6 kB 5.5 MB/s eta 0:00:00
# Downloading polars_runtime_32-1.35.1-cp39-abi3-macosx_10_12_x86_64.whl (40.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 MB 12.4 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: polars-runtime-32, polars
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [polars]2m1/2 [polars]
# Successfully installed polars-1.35.1 polars-runtime-32-1.35.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import polars as pl
import datetime as dt

df = pl.DataFrame(
    {
        "name": ["Alice Archer", "Ben Brown", "Chloe Cooper", "Daniel Donovan"],
        "birthdate": [
            dt.date(1997, 1, 10),
            dt.date(1985, 2, 15),
            dt.date(1983, 3, 22),
            dt.date(1981, 4, 30),
        ],
        "weight": [57.9, 72.5, 53.6, 83.1],  # (kg)
        "height": [1.56, 1.77, 1.65, 1.75],  # (m)
    }
)

print(df)
# Out:
# shape: (4, 4)
# ┌────────────────┬────────────┬────────┬────────┐
# │ name           ┆ birthdate  ┆ weight ┆ height │
# │ ---            ┆ ---        ┆ ---    ┆ ---    │
# │ str            ┆ date       ┆ f64    ┆ f64    │
# ╞════════════════╪════════════╪════════╪════════╡
# │ Alice Archer   ┆ 1997-01-10 ┆ 57.9   ┆ 1.56   │
# │ Ben Brown      ┆ 1985-02-15 ┆ 72.5   ┆ 1.77   │
# │ Chloe Cooper   ┆ 1983-03-22 ┆ 53.6   ┆ 1.65   │
# │ Daniel Donovan ┆ 1981-04-30 ┆ 83.1   ┆ 1.75   │
# └────────────────┴────────────┴────────┴────────┘
